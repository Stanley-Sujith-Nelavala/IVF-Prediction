# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("C:\\Users\\stanl\\Desktop\\Internships\\IITK Oswald sir\\IVF\\Datset.csv")
print(train.shape)
# Out:
# (158519, 95)
# C:\Users\stanl\AppData\Local\Temp\ipykernel_22032\2653788074.py:1: DtypeWarning: Columns (6,7,29,31,32,43,48,50,51,52,53,54,77,83,89,90,91,92) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv("C:\\Users\\stanl\\Desktop\\Internships\\IITK Oswald sir\\IVF\\Datset.csv")

# %%
train=train.head(15000)
train.shape
train
# Out:
#       Patient Age at Treatment  \
# 0                        40-42
# 1                        45-50
# 2                        35-37
# 3                      18 - 34
# 4                      18 - 34
# ...                        ...
# 14995                    43-44
# 14996                    38-39
# 14997                    35-37
# 14998                    38-39
# 14999                  18 - 34
#
#        Date patient started trying to become pregnant OR date of last pregnancy  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14995                                                NaN
# 14996                                                NaN
# ...

# %%
NAs = pd.concat([train.isnull().sum()], axis=1, keys=["train"])
list1 = NAs[NAs.sum(axis=1) > 14250]
list1
# Out:
#                                                     train
# Date patient started trying to become pregnant ...  14942
# PGD treatment                                       14856
# PGS                                                 14766
# PGS Treatment                                       14885
# Date of Egg Thawing                                 14892
# Heart One Birth Congenital Abnormalities            15000
# Heart Two Weeks Gestation                           14524
# Heart Two Birth Outcome                             14446
# Heart Two Birth Weight                              14526
# Heart Two Sex                                       14522
# Heart Two Delivery Date                             14524
# Heart Two Birth Congenital Abnormalities            15000
# Heart Three Weeks Gestation                         14983
# Heart Three Birth Outcome                           14978
# Heart Three Birth Weight                            14983
# ...

# %%
newtrain = train.drop(columns = ["Heart Four Birth Congenital Abnormalities","Date patient started trying to become pregnant OR date of last pregnancy",
"PGD treatment", 
"PGS",
"PGS Treatment",
"Date of Egg Thawing",
"Heart One Birth Congenital Abnormalities",
"Heart Two Weeks Gestation",
"Heart Two Birth Outcome",
"Heart Two Birth Weight",
"Heart Two Sex",
"Heart Two Delivery Date",
"Heart Two Birth Congenital Abnormalities",
"Heart Three Weeks Gestation",
"Heart Three Birth Outcome",
"Heart Three Birth Weight",
"Heart Three Sex",
"Heart Three Delivery Date",
"Heart Three Birth Congenital Abnormalities",
"Heart Four Weeks Gestation",
"Heart Four Birth Outcome",
"Heart Four Birth Weight",
"Heart Four Sex",
"Heart Four Delivery Date",
"Heart Four Birth Congenital Abnormalities"],axis=1)

# %%
NAs = pd.concat([newtrain.isnull().sum()], axis=1, keys=["newtrain"])
list2 = NAs[NAs.sum(axis=1) > 0]
list2
# Out:
#                                  newtrain
# Type of Ovulation Induction          4840
# Egg Donor Age at Registration       14210
# Sperm Donor Age at Registration     13908
# Date of Egg Collection               4507
# Date of Egg Mixing                   5189
# Date of Embryo Thawing              10952
# Date of Embryo Transfer              3208
# Live Birth Occurrence               11299
# Early Outcome                        3209
# Heart One Weeks Gestation           11379
# Heart One Birth Outcome             10792
# Heart One Birth Weight              11387
# Heart OneSex                        11361
# Heart One Delivery Date             11371

# %%
newtrain.to_csv("newdata.csv",index = False)

# %%
newtrain
# Out:
#       Patient Age at Treatment  \
# 0                        40-42
# 1                        45-50
# 2                        35-37
# 3                      18 - 34
# 4                      18 - 34
# ...                        ...
# 14995                    43-44
# 14996                    38-39
# 14997                    35-37
# 14998                    38-39
# 14999                  18 - 34
#
#       Total Number of Previous cycles, Both IVF and DI  \
# 0                                                    2
# 1                                                    3
# 2                                                    0
# 3                                                    2
# 4                                                    5
# ...                                                ...
# 14995                                                2
# 14996                                                4
# 14997                                                3
# ...

# %%
list2
# Out:
#                                  newtrain
# Type of Ovulation Induction          4840
# Egg Donor Age at Registration       14210
# Sperm Donor Age at Registration     13908
# Date of Egg Collection               4507
# Date of Egg Mixing                   5189
# Date of Embryo Thawing              10952
# Date of Embryo Transfer              3208
# Live Birth Occurrence               11299
# Early Outcome                        3209
# Heart One Weeks Gestation           11379
# Heart One Birth Outcome             10792
# Heart One Birth Weight              11387
# Heart OneSex                        11361
# Heart One Delivery Date             11371

# %%
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], []]
