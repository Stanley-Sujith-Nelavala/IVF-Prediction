# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# # Data Preprocessing

# %%
#import dataset
df = pd.read_csv(r"C:\Users\stanl\Desktop\Internships\IITK Oswald sir\IVF\Datset.csv")
df
# Out:
#        Patient Age at Treatment  \
# 0                         40-42
# 1                         45-50
# 2                         35-37
# 3                       18 - 34
# 4                       18 - 34
# ...                         ...
# 158514                  18 - 34
# 158515                    38-39
# 158516                    38-39
# 158517                  18 - 34
# 158518                  18 - 34
#
#         Date patient started trying to become pregnant OR date of last pregnancy  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 158514                                                NaN
# 158515                                                NaN
# ...

# %%
#dropping the columns with more than one NAN values
df_new = df.dropna(axis='columns')
df_new
# Out:
#        Patient Age at Treatment  \
# 0                         40-42
# 1                         45-50
# 2                         35-37
# 3                       18 - 34
# 4                       18 - 34
# ...                         ...
# 158514                  18 - 34
# 158515                    38-39
# 158516                    38-39
# 158517                  18 - 34
# 158518                  18 - 34
#
#        Total Number of Previous cycles, Both IVF and DI  \
# 0                                                     2
# 1                                                     3
# 2                                                     0
# 3                                                     2
# 4                                                     5
# ...                                                 ...
# 158514                                                3
# 158515                                                0
# 158516                                                1
# ...

# %%
# Checking for null values in the data frame
df_new.isnull().sum()
# Out:
# Patient Age at Treatment                                          0
# Total Number of Previous cycles, Both IVF and DI                  0
# Total Number of Previous treatments, Both IVF and DI at clinic    0
# Total Number of Previous IVF cycles                               0
# Total Number of Previous DI cycles                                0
# Total number of previous pregnancies, Both IVF and DI             0
# Total number of IVF pregnancies                                   0
# Total number of DI pregnancies                                    0
# Total number of live births - conceived through IVF or DI         0
# Total number of live births - conceived through IVF               0
# Total number of live births - conceived through DI                0
# Type of Infertility - Female Primary                              0
# Type of Infertility - Female Secondary                            0
# Type of Infertility - Male Primary                                0
# ...

# %%
#Printing the number of rows and colunms
print("There are {} rows and {} columns.".format(df_new.shape[0],df_new.shape[1]))
# Out:
# There are 158519 rows and 35 columns.

# %%
# Converting the Categorical data into numerical Data
df_new['Patient Age at Treatment'].replace(['18 - 34', '35-37','38-39','40-42','43-44','45-50'],
                        [0, 1, 2, 3, 4, 5], inplace=True)
df_new
# Out:
#        Patient Age at Treatment  \
# 0                             3
# 1                             5
# 2                             1
# 3                             0
# 4                             0
# ...                         ...
# 158514                        0
# 158515                        2
# 158516                        2
# 158517                        0
# 158518                        0
#
#        Total Number of Previous cycles, Both IVF and DI  \
# 0                                                     2
# 1                                                     3
# 2                                                     0
# 3                                                     2
# 4                                                     5
# ...                                                 ...
# 158514                                                3
# 158515                                                0
# 158516                                                1
# ...

# %%
# Dropping the columns with '999' as age.
df_new.drop(df_new[(df_new['Patient Age at Treatment'] == '999')].index, inplace=True)
df_new
# Out:
#        Patient Age at Treatment  \
# 0                             3
# 1                             5
# 2                             1
# 3                             0
# 4                             0
# ...                         ...
# 158514                        0
# 158515                        2
# 158516                        2
# 158517                        0
# 158518                        0
#
#        Total Number of Previous cycles, Both IVF and DI  \
# 0                                                     2
# 1                                                     3
# 2                                                     0
# 3                                                     2
# 4                                                     5
# ...                                                 ...
# 158514                                                3
# 158515                                                0
# 158516                                                1
# ...

# %%
df_new.drop(df_new[(df_new['Type of treatment - IVF or DI'] != 'IVF')].index, inplace=True)
df_new
# Out:
#        Patient Age at Treatment  \
# 0                             3
# 1                             5
# 2                             1
# 3                             0
# 4                             0
# ...                         ...
# 148101                        0
# 148102                        0
# 148103                        1
# 148104                        3
# 148105                        0
#
#        Total Number of Previous cycles, Both IVF and DI  \
# 0                                                     2
# 1                                                     3
# 2                                                     0
# 3                                                     2
# 4                                                     5
# ...                                                 ...
# 148101                                                0
# 148102                                                1
# 148103                                                1
# ...

# %%
df_new.drop(df_new[(df_new['Specific treatment type'] != 'IVF')].index, inplace=True)
df_new
# Out:
#        Patient Age at Treatment  \
# 0                             3
# 2                             1
# 15                            1
# 17                            0
# 19                            0
# ...                         ...
# 148097                        2
# 148099                        0
# 148101                        0
# 148103                        1
# 148104                        3
#
#        Total Number of Previous cycles, Both IVF and DI  \
# 0                                                     2
# 2                                                     0
# 15                                                    0
# 17                                                    0
# 19                                                    0
# ...                                                 ...
# 148097                                                0
# 148099                                                0
# 148101                                                0
# ...

# %%
df_new.drop(df_new[(df_new['Sperm From'] != 'Partner')].index, inplace=True)
df_new
# Out:
#        Patient Age at Treatment  \
# 0                             3
# 2                             1
# 15                            1
# 17                            0
# 19                            0
# ...                         ...
# 148097                        2
# 148099                        0
# 148101                        0
# 148103                        1
# 148104                        3
#
#        Total Number of Previous cycles, Both IVF and DI  \
# 0                                                     2
# 2                                                     0
# 15                                                    0
# 17                                                    0
# 19                                                    0
# ...                                                 ...
# 148097                                                0
# 148099                                                0
# 148101                                                0
# ...

# %%
df_new['Type of treatment - IVF or DI'].replace(['IVF'],[1], inplace=True)
df_new
# Out:
#        Patient Age at Treatment  \
# 0                             3
# 2                             1
# 15                            1
# 17                            0
# 19                            0
# ...                         ...
# 148097                        2
# 148099                        0
# 148101                        0
# 148103                        1
# 148104                        3
#
#        Total Number of Previous cycles, Both IVF and DI  \
# 0                                                     2
# 2                                                     0
# 15                                                    0
# 17                                                    0
# 19                                                    0
# ...                                                 ...
# 148097                                                0
# 148099                                                0
# 148101                                                0
# ...

# %%
df_new['Specific treatment type'].replace(['IVF'],[1], inplace=True)
df_new
# Out:
#        Patient Age at Treatment  \
# 0                             3
# 2                             1
# 15                            1
# 17                            0
# 19                            0
# ...                         ...
# 148097                        2
# 148099                        0
# 148101                        0
# 148103                        1
# 148104                        3
#
#        Total Number of Previous cycles, Both IVF and DI  \
# 0                                                     2
# 2                                                     0
# 15                                                    0
# 17                                                    0
# 19                                                    0
# ...                                                 ...
# 148097                                                0
# 148099                                                0
# 148101                                                0
# ...

# %%
df_new['Sperm From'].replace(['Partner'],[1], inplace=True)
df_new
# Out:
#        Patient Age at Treatment  \
# 0                             3
# 2                             1
# 15                            1
# 17                            0
# 19                            0
# ...                         ...
# 148097                        2
# 148099                        0
# 148101                        0
# 148103                        1
# 148104                        3
#
#        Total Number of Previous cycles, Both IVF and DI  \
# 0                                                     2
# 2                                                     0
# 15                                                    0
# 17                                                    0
# 19                                                    0
# ...                                                 ...
# 148097                                                0
# 148099                                                0
# 148101                                                0
# ...

# %%
df_new.drop(["Year of Treatment"], axis = 1, inplace = True)
df_new
# Out:
#        Patient Age at Treatment  \
# 0                             3
# 2                             1
# 15                            1
# 17                            0
# 19                            0
# ...                         ...
# 148097                        2
# 148099                        0
# 148101                        0
# 148103                        1
# 148104                        3
#
#        Total Number of Previous cycles, Both IVF and DI  \
# 0                                                     2
# 2                                                     0
# 15                                                    0
# 17                                                    0
# 19                                                    0
# ...                                                 ...
# 148097                                                0
# 148099                                                0
# 148101                                                0
# ...

# %%
df_new.drop(["Number of foetal sacs with fetal pulsation"], axis = 1, inplace = True)
df_new
# Out:
#        Patient Age at Treatment  \
# 0                             3
# 2                             1
# 15                            1
# 17                            0
# 19                            0
# ...                         ...
# 148097                        2
# 148099                        0
# 148101                        0
# 148103                        1
# 148104                        3
#
#        Total Number of Previous cycles, Both IVF and DI  \
# 0                                                     2
# 2                                                     0
# 15                                                    0
# 17                                                    0
# 19                                                    0
# ...                                                 ...
# 148097                                                0
# 148099                                                0
# 148101                                                0
# ...

# %%
algo_temp = df_new.iloc[0:20]
algo_temp
# Out:
#    Patient Age at Treatment Total Number of Previous cycles, Both IVF and DI  \
# 0                         3                                                2
# 2                         1                                                0
# 15                        1                                                0
# 17                        0                                                0
# 19                        0                                                0
# 20                        0                                                0
# 25                        3                                                0
# 27                        3                                                3
# 32                        3                                                4
# 34                        1                                                5
# 37                        1                                                1
# ...

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
# Splitting into target variable and other attributes.
X = algo_temp.iloc[:, 0:32]
print(f"X:{X}")
Y = algo_temp.iloc[:,-1]
print(f"Y:{Y}")
# Out:
# X:   Patient Age at Treatment Total Number of Previous cycles, Both IVF and DI  \
# 0                         3                                                2
# 2                         1                                                0
# 15                        1                                                0
# 17                        0                                                0
# 19                        0                                                0
# 20                        0                                                0
# 25                        3                                                0
# 27                        3                                                3
# 32                        3                                                4
# 34                        1                                                5
# 37                        1                                                1
# ...

# %%
# Splitting the dataset for training and test purpose
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 100)

# %%
# Performing training with gini index
clf_entropy = DecisionTreeClassifier(criterion = "entropy", random_state = 100,max_depth = 3, min_samples_leaf = 5)
  
# Performing training
clf_entropy.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5,
#                        random_state=100)

# %%
y_pred = clf_entropy.predict(X_test)
print("Predicted values:")
print(y_pred)
# Out:
# Predicted values:
# [0 0 0 0 0 0]

# %%
print("Confusion Matrix:\n",confusion_matrix(y_test, y_pred))
      
print ("Accuracy :\n",accuracy_score(y_test,y_pred)*100)
      
print("Report :\n",classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[6]]
# Accuracy :
#  100.0
# Report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6

# %% [markdown]
# # K-Nearest Neighbour Classifier

# %%
#KNN Classifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
             X, Y, test_size = 0.2, random_state=42)
 
knn = KNeighborsClassifier(n_neighbors=4)
 
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
# Calculating the accuracy of the model
print(knn.score(X_test, y_test))
# Out:
# 0.75

# %%
neighbors = np.arange(1, 5)
train_accuracy = np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))
 
# Loop over K values
for i, k in enumerate(neighbors):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
     
    # Compute training and test data accuracy
    train_accuracy[i] = knn.score(X_train, y_train)
    test_accuracy[i] = knn.score(X_test, y_test)
 
# Generate plot
plt.plot(neighbors, test_accuracy, label = 'Testing dataset Accuracy')
plt.plot(neighbors, train_accuracy, label = 'Training dataset Accuracy')
 
plt.legend()
plt.xlabel('n_neighbors')
plt.ylabel('Accuracy')
plt.show()
